# %%
import pandas as pd

# %%
df = pd.read_csv("newuninsured.csv")
df.head()
# Out:
#   Table with row headers in column A and column headers in rows 6 through 10  \
# 0                               Appendix Table A-5.
# 1  Percentage of People Without Health Insurance ...
# 2  (Numbers in thousands. Civilian noninstitution...
# 3                                                NaN
# 4                                              State
#
#                                           Unnamed: 1      Unnamed: 2  \
# 0                                                NaN             NaN
# 1                                                NaN             NaN
# 2                                                NaN             NaN
# 3                                                NaN             NaN
# 4  Medicaid Expansion State?        Yes (Y) or No...  2013 Uninsured
#
#   Unnamed: 3      Unnamed: 4 Unnamed: 5      Unnamed: 6 Unnamed: 7  \
# 0        NaN             NaN        NaN             NaN        NaN
# 1        NaN             NaN        NaN             NaN        NaN
# ...

# %%
df[:20]
# Out:
#    Table with row headers in column A and column headers in rows 6 through 10  \
# 0                                Appendix Table A-5.
# 1   Percentage of People Without Health Insurance ...
# 2   (Numbers in thousands. Civilian noninstitution...
# 3                                                 NaN
# 4                                               State
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                United States…………..
# 11                                                NaN
# 12                               Alabama……………………………….
# 13                             Alaska……………………………………..
# 14                             Arizona…………………………………..
# 15                              Arkansas……………………………….
# ...

# %%
df.drop(df.index[0:4], axis=0, inplace=True)
df.reset_index(inplace=True,drop=True)
df[:20]
# Out:
#    Table with row headers in column A and column headers in rows 6 through 10  \
# 0                                               State
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                 United States…………..
# 7                                                 NaN
# 8                                Alabama……………………………….
# 9                              Alaska……………………………………..
# 10                             Arizona…………………………………..
# 11                              Arkansas……………………………….
# 12                             California………………………………
# 13                              Colorado……………………………….
# 14                              Connecticut…………………………
# 15                              Delaware……………………………….
# ...

# %%
df.drop(df.index[1:6], axis=0, inplace=True)
df.reset_index(inplace=True,drop=True)
df[:20]
# Out:
#    Table with row headers in column A and column headers in rows 6 through 10  \
# 0                                               State
# 1                                 United States…………..
# 2                                                 NaN
# 3                                Alabama……………………………….
# 4                              Alaska……………………………………..
# 5                              Arizona…………………………………..
# 6                               Arkansas……………………………….
# 7                              California………………………………
# 8                               Colorado……………………………….
# 9                               Connecticut…………………………
# 10                              Delaware……………………………….
# 11                         District of Columbia…………..
# 12                              Florida……………………………………
# 13                                                NaN
# 14                               Georgia…………………………………
# 15                              Hawaii…………………………………….
# ...

# %%
df.columns = df.iloc[0]
df.head()
# Out:
# 0                   State Medicaid Expansion State?        Yes (Y) or No (N)1  \
# 0                   State  Medicaid Expansion State?        Yes (Y) or No...
# 1     United States…………..                                                  X
# 2                     NaN                                                NaN
# 3    Alabama……………………………….                                                  N
# 4  Alaska……………………………………..                                                 +Y
#
# 0  2013 Uninsured  NaN  2016 Uninsured  NaN  2017 Uninsured  NaN  \
# 0  2013 Uninsured  NaN  2016 Uninsured  NaN  2017 Uninsured  NaN
# 1          45,181  200          27,304  162          28,019  188
# 2             NaN  NaN             NaN  NaN             NaN  NaN
# 3             645   17             435   14             449   16
# 4             132    7             101    6              98    6
#
# 0  Difference in Uninsured  NaN       NaN      NaN  NaN  NaN
# ...

# %%
df.drop(0, axis=0, inplace=True)
df.head()
# Out:
# 0                   State Medicaid Expansion State?        Yes (Y) or No (N)1  \
# 1     United States…………..                                                  X
# 2                     NaN                                                NaN
# 3    Alabama……………………………….                                                  N
# 4  Alaska……………………………………..                                                 +Y
# 5  Arizona…………………………………..                                                  Y
#
# 0 2013 Uninsured  NaN 2016 Uninsured  NaN 2017 Uninsured  NaN  \
# 1         45,181  200         27,304  162         28,019  188
# 2            NaN  NaN            NaN  NaN            NaN  NaN
# 3            645   17            435   14            449   16
# 4            132    7            101    6             98    6
# 5          1,118   24            681   21            695   20
#
# 0 Difference in Uninsured  NaN       NaN      NaN  NaN  NaN
# 1                    *715  248  *-17,161   \t275   NaN  NaN
# ...

# %%
df = df[["State","2017 Uninsured"]]

# %%
df.drop(df.index[57:], axis=0, inplace=True)
df.reset_index(inplace=True,drop=True)
df.shape
# Out:
# (57, 2)

# %%
df.dropna(axis=0, inplace=True)
df.reset_index(inplace=True, drop=True)

# %%
#df['State1'] = df['State'].str.replace('.', '')
df.head()
# Out:
# 0                   State 2017 Uninsured
# 0     United States…………..         28,019
# 1    Alabama……………………………….            449
# 2  Alaska……………………………………..             98
# 3  Arizona…………………………………..            695
# 4   Arkansas……………………………….            232

# %%
#df['State'].str.strip()
df['2017 Uninsured'] = df['2017 Uninsured'].str.replace(',', '')

# %%
df.head()
# Out:
# 0                 State 2017 Uninsured
# 0     United States…………          28019
# 1   Alabama………………………………            449
# 2  Alaska……………………………………             98
# 3  Arizona…………………………………            695
# 4  Arkansas………………………………            232

# %%
df.to_csv("UninsuredCount.csv", index=False)

# %% [markdown]
# ## Fastfood improve

# %%
df = pd.read_csv("./Final Data/fastfoodloc.csv")
df.head()
# Out:
#                      city  latitude  longitude              name    zip state
# 0                 Massena  44.92130  -74.89021        McDonald's  13662    NY
# 1  Washington Court House  39.53255  -83.44526           Wendy's  43160    OH
# 2               Maysville  38.62736  -83.79141  Frisch's Big Boy  41056    KY
# 3                 Massena  44.95008  -74.84553        McDonald's  13662    NY
# 4                  Athens  39.35155  -82.09728   OMG! Rotisserie  45701    OH

# %%
states = {"AL":"Alabama","AK":"Alaska","AZ":"Arizona","AR":"Arkansas","CA":"California","CO":"Colorado","CT":"Connecticut","DE":"Delaware","FL":"Florida","GA":"Georgia","HI":"Hawaii","ID":"Idaho","IL":"Illinois","IN":"Indiana","IA":"Iowa","KS":"Kansas","KY":"Kentucky","LA":"Louisiana","ME":"Maine","MD":"Maryland","MA":"Massachusetts","MI":"Michigan","MN":"Minnesota","MS":"Mississippi","MO":"Missouri","MT":"Montana","NE":"Nebraska","NV":"Nevada","NH":"New Hampshire","NJ":"New Jersey","NM":"New Mexico","NY":"New York","NC":"North Carolina","ND":"North Dakota","OH":"Ohio","OK":"Oklahoma","OR":"Oregon","PA":"Pennsylvania","RI":"Rhode Island","SC":"South Carolina","SD":"South Dakota","TN":"Tennessee","TX":"Texas","UT":"Utah","VT":"Vermont","VA":"Virginia","WA":"Washington","WV":"West Virginia","WI":"Wisconsin","WY":"Wyoming"}

# %%
df['state'] = df['state'].map(states)
df.head()
# Out:
#                      city  latitude  longitude              name    zip  \
# 0                 Massena  44.92130  -74.89021        McDonald's  13662
# 1  Washington Court House  39.53255  -83.44526           Wendy's  43160
# 2               Maysville  38.62736  -83.79141  Frisch's Big Boy  41056
# 3                 Massena  44.95008  -74.84553        McDonald's  13662
# 4                  Athens  39.35155  -82.09728   OMG! Rotisserie  45701
#
#       state
# 0  New York
# 1      Ohio
# 2  Kentucky
# 3  New York
# 4      Ohio

# %%
df.rename({'state': 'State'}, axis=1, inplace=True)
df.head()
# Out:
#                      city  latitude  longitude              name    zip  \
# 0                 Massena  44.92130  -74.89021        McDonald's  13662
# 1  Washington Court House  39.53255  -83.44526           Wendy's  43160
# 2               Maysville  38.62736  -83.79141  Frisch's Big Boy  41056
# 3                 Massena  44.95008  -74.84553        McDonald's  13662
# 4                  Athens  39.35155  -82.09728   OMG! Rotisserie  45701
#
#       State
# 0  New York
# 1      Ohio
# 2  Kentucky
# 3  New York
# 4      Ohio

# %%
df.to_csv("./Final Data/fastfoodloc.csv", index=False)

# %% [markdown]
# ## Air quality

# %%
df = pd.read_csv("./raw data/annual_aqi_by_county_2017.csv")
df.head()
# Out:
#      State   County  Year  Days with AQI  Good Days  Moderate Days  \
# 0  Alabama  Baldwin  2017            270        241             28
# 1  Alabama     Clay  2017            118        104             14
# 2  Alabama  Colbert  2017            283        265             18
# 3  Alabama   DeKalb  2017            359        329             30
# 4  Alabama   Elmore  2017            226        221              5
#
#    Unhealthy for Sensitive Groups Days  Unhealthy Days  Very Unhealthy Days  \
# 0                                    1               0                    0
# 1                                    0               0                    0
# 2                                    0               0                    0
# 3                                    0               0                    0
# 4                                    0               0                    0
#
#    Hazardous Days  Max AQI  90th Percentile AQI  Median AQI  Days CO  \
# ...

# %%
df.columns
# Out:
# Index(['State', 'County', 'Year', 'Days with AQI', 'Good Days',
#        'Moderate Days', 'Unhealthy for Sensitive Groups Days',
#        'Unhealthy Days', 'Very Unhealthy Days', 'Hazardous Days', 'Max AQI',
#        '90th Percentile AQI', 'Median AQI', 'Days CO', 'Days NO2',
#        'Days Ozone', 'Days SO2', 'Days PM2.5', 'Days PM10'],
#       dtype='object')

# %%
df = df[['State', 'County','Median AQI']]
df.head()
# Out:
#      State   County  Median AQI
# 0  Alabama  Baldwin          36
# 1  Alabama     Clay          30
# 2  Alabama  Colbert          37
# 3  Alabama   DeKalb          39
# 4  Alabama   Elmore          35

# %%
df = df.groupby(['State'])['Median AQI'].mean().reset_index()

# %%
df.to_csv("./Final Data/airquality.csv", index=False)
